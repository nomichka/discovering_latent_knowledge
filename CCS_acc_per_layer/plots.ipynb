# %%
import matplotlib.pyplot as plt

ccs_accuracy = [0.6, 0.72, 0.72, 0.52, 0.6, 0.64, 0.56, 0.56, 0.6, 0.6, 0.6, 0.68, 0.64, 0.68, 0.64, 0.72, 0.56, 0.6, 0.6, 0.68, 0.68, 0.56, 0.52, 0.52, 0.68, 0.52, 0.56, 0.56, 0.68]
logistic_regression_accuracy = [0.4, 0.36, 0.28, 0.48, 0.48, 0.48] 
logistic_regression_accuracy += [0.52]*19
logistic_regression_accuracy += [0.6, 0.52, 0.6, 0.52, 0.6, 0.84]

plt.plot(ccs_accuracy, label='CCS Accuracy')
plt.plot(logistic_regression_accuracy, label='Logistic Regression Accuracy')
plt.legend()
plt.savefig('ccs_vs_log_accuracy.png')
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.savefig('ccs_vs_log_accuracy.png')
